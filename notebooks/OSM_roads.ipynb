# %%
import geopandas as gpd
import osmnx as ox
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Import and analyse noise dataset

# %%
noise_streets = gpd.read_file("../layers/BCN_noise_streets.gpkg")
print(noise_streets.crs)  #CRS = Coordinate Reference System
print(noise_streets.shape)
print(noise_streets.columns.tolist())
print("Number of street segments:", len(noise_streets))
# Out:
# EPSG:25831
# (15115, 30)
# ['TRAM', 'TOTAL_D', 'TOTAL_E', 'TOTAL_N', 'TOTAL_DEN', 'TRANSIT_D', 'TRANSIT_E', 'TRANSIT_N', 'TRANSIT_DEN', 'GI_TR_D', 'GI_TR_E', 'GI_TR_N', 'GI_TR_DEN', 'FFCC_D', 'FFCC_E', 'FFCC_N', 'FFCC_DEN', 'INDUST_D', 'INDUST_E', 'INDUST_N', 'INDUST_DEN', 'VIANANTS_D', 'VIANANTS_E', 'OCI_N', 'PATIS_D', 'PATIS_E', 'geometry_type', 'start', 'end', 'geometry']
# Number of street segments: 15115

# %% [markdown]
# Roads - OSM

# %%
roads = ox.features_from_place("Barcelona, Spain", tags={"highway": True}) #connects to OSM and downloads all features within Barcelona that match the tags you specify
roads = roads[roads.geometry.type == 'LineString'].to_crs(noise_streets.crs) #keeps only line geometries and reprojects to match the CRS of noise_streets (otherwise they come in EPSG:4326)
print(roads.crs)
print(roads.columns.tolist())
# Out:
# EPSG:25831
# ['geometry', 'highway', 'traffic_signals', 'traffic_signals:direction', 'button_operated', 'crossing', 'tactile_paving', 'traffic_signals:sound', 'traffic_signals:vibration', 'crossing:markings', 'crossing:signals', 'kerb', 'supervised', 'crossing:island', 'bicycle', 'source', 'traffic_signals:arrow', 'name', 'direction', 'loc_name', 'maxspeed', 'note', 'operator', 'check_date:crossing', 'source:date', 'ref', 'bench', 'bus', 'network', 'passenger_information_display', 'public_transport', 'route_ref', 'shelter', 'traffic_calming', 'speed_camera:direction', 'noref', 'noname', 'distance', 'bin', 'lit', 'name:ca', 'foot', 'destination:ref', 'traffic_sign', 'colour:ref', 'railway', 'wheelchair', 'url', 'side', 'network:short', 'network:wikidata', 'check_date:traffic_signals:sound', 'surface', 'check_date:shelter', 'website', 'alt_name', 'kerb:approach_aid', 'passenger_information_display:speech_output', 'description', 'check_date:tactile_paving', 'barrier', 'network:bus', 'network:guid', 'network:wikipedia', 'designation', 'colour', 'mapillary', 'segregated', 'departures_board', 'access', 'fee', 'opening_hours', 'covered', 'operator:wikidata', 'toilets:wheelchair', 'name:2022', 'survey:date', 'check_date:traffic_signals:vibration', 'disused:public_transport', 'old_name', 'level', 'was:crossing', 'was:highway', 'local_ref', 'indoor', 'crossing:-2020', 'highway:-2020', 'traffic_signals:-2020', 'cycleway:crossing:markings', 'footway:crossing:markings', 'wikidata', 'wikimedia_commons', 'wikipedia', 'operator:short', 'name:ko', 'lamp_type', 'description:ru', 'name:en', 'conveying', 'name:es', 'check_date:bin', 'internet_access', 'name:etymology:wikidata', 'alt_name:ca', 'was:name', 'lamp_mount', 'ele', 'postal_code', 'name:-2023', 'official_ref', 'name:ru', 'crossing:barrier', 'bicycle:-2020', 'vehicle', 'red_turn:bicycle', 'crossing:continuous', 'cycleway', 'layer', 'disused:highway', 'amenity', 'support', 'motor_vehicle', 'was:traffic_signals:direction', 'traffic_signals:sound:remote_operated', 'was:ref', 'level:ref', 'inscription', 'parking', 'artwork_type', 'panoramax', 'tourism', 'board:title', 'fixme', 'hiking', 'information', 'proposed:highway', 'route:name', 'dog', 'height', 'light:shape', 'pole:material', 'maxweight', 'camera:mount', 'camera:type', 'man_made', 'surveillance', 'surveillance:type', 'construction', 'elevator', 'start_date', 'proposed:crossing', 'check_date', 'lanes', 'lanes:backward', 'lanes:forward', 'official_name', 'oneway', 'smoothness', 'name:1942-2018', 'name:etymology:wikipedia', 'psv', 'junction', 'oneway:bicycle', 'sidewalk', 'footway', 'name:be', 'source:maxspeed', 'sidewalk:both', 'cycleway:both', 'government', 'maxlength', 'motor_vehicle:conditional', 'hov', 'tourist_bus', 'parking:left', 'parking:right', 'parking:right:orientation', 'zone:maxspeed', 'parking:left:orientation', 'lane_markings', 'width', 'psv:lanes', 'turn:lanes', 'wikipedia:es', 'change:lanes', 'emergency', 'oneway:emergency', 'oneway:motor_vehicle', 'busway:right', 'cycleway:right', 'sidewalk:both:surface', 'access:conditional', 'maxspeed:type', 'incline', 'bus:lanes:backward', 'oneway:bus', 'sidewalk:left', 'sidewalk:right', 'maxheight', 'parking:both', 'parking:both:orientation', 'area', 'cycleway:left', 'cycleway:left:lane', 'goods', 'cycleway:right:lane', 'source:width', 'parking:both:restriction', 'horse', 'cycleway:both:lane', 'name:-2025', 'service', 'cycleway:left:oneway', 'sett:pattern', 'sett:shape', 'parking:left:markings', 'check_date:surface', 'inline_skates', 'highway:-2019', 'residents', 'services', 'name:pronunciation', 'sidewalk:left:bicycle', 'old_name:es', 'tunnel', 'shoulder', 'change:lanes:backward', 'change:lanes:forward', 'name:-2022', 'old_name:ca', 'customers', 'taxi', 'psv:lanes:backward', 'psv:lanes:forward', 'highway:2019', 'maxspeed:2019', 'oneway:2019', 'highway:-2023', 'lanes:-2023', 'maxspeed:-2023', 'name:ca:-2023', 'surface:-2023', 'place', 'handrail', 'was:bicycle', 'area:highway', 'name:he', 'maxwid ...

# %%
roads.plot(figsize=(10, 10), column='highway', linewidth=0.5, legend=True)

#https://osmnx.readthedocs.io/en/stable/user-reference.html#osmnx.features.features_from_place
# Out:
# <Axes: >

# %% [markdown]
# Filter roads categories

# %%
# Filter to only primary and secondary roads
categories = ['busway', 'living_street','motorway','pedestrian','residential','primary', 'secondary', 'tertiary', 'trunk', 'track']
roads_filtered = roads[roads['highway'].isin(categories)]
print(f"Original: {len(roads)}, Filtered: {len(roads_filtered)}")
roads_filtered.plot(figsize=(10, 10), column='highway', linewidth=0.5, legend=True)
# Out:
# <Axes: >

# %% [markdown]
# Assign to noise street the category of the closest osm road

# %%
# Find the nearest road for each noise street segment
print(f"Original noise_streets: {noise_streets.shape}")
# Reset index before spatial join
noise_streets_clean = noise_streets[['geometry','TOTAL_D','TOTAL_E','TOTAL_N']].reset_index(drop=False)
roads_clean = roads_filtered[['geometry', 'highway']].reset_index(drop=True)

dataset = gpd.sjoin_nearest(
    noise_streets_clean, 
    roads_clean,
    how='left'
)

# Now filter to keep only one row per street_id if needed
dataset = dataset.drop_duplicates(subset=['index'], keep='first')
print(f"Noise streets after nearest road join: {dataset.shape}")
print(dataset.columns.tolist())
# Out:
# Original noise_streets: (15115, 30)
# Noise streets after nearest road join: (15115, 7)
# ['index', 'geometry', 'TOTAL_D', 'TOTAL_E', 'TOTAL_N', 'index_right', 'highway']

# %% [markdown]
# Create data frame

# %%
dataset = pd.DataFrame({
    "street_id": dataset['index'],
    "noise_day": dataset['TOTAL_D'],
    "noise_evening": dataset['TOTAL_E'],
    "noise_night": dataset['TOTAL_N'],
    "road_category": dataset['highway']    
}).fillna(0) #fillna(0) to replace any NaN values (which indicate no signals or POIs in that segment) with 0
dataset.head(10)
# Out:
#    street_id      noise_day  noise_evening    noise_night  road_category
# 0          0  70 - 75 dB(A)  65 - 70 dB(A)  60 - 65 dB(A)    residential
# 1          1  45 - 50 dB(A)  45 - 50 dB(A)     < 40 dB(A)     pedestrian
# 2          2  55 - 60 dB(A)  55 - 60 dB(A)  50 - 55 dB(A)        footway
# 3          3  60 - 65 dB(A)  55 - 60 dB(A)  60 - 65 dB(A)  living_street
# 4          4  55 - 60 dB(A)  55 - 60 dB(A)  50 - 55 dB(A)    residential
# 5          5  55 - 60 dB(A)  55 - 60 dB(A)  50 - 55 dB(A)    residential
# 6          6  50 - 55 dB(A)  50 - 55 dB(A)  45 - 50 dB(A)    residential
# 7          7  45 - 50 dB(A)  45 - 50 dB(A)  40 - 45 dB(A)    residential
# 8          8  55 - 60 dB(A)  55 - 60 dB(A)  50 - 55 dB(A)        footway
# 9          9  60 - 65 dB(A)  55 - 60 dB(A)  50 - 55 dB(A)    residential

# %% [markdown]
# TODO: add more info from roads
