# %%
import geopandas as gpd
import osmnx as ox
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Import and analyse noise dataset

# %%
osm_roads = gpd.read_file("../../layers/bcn_osmnx_edges.gpkg")
print(osm_roads.crs)  #CRS = Coordinate Reference System
print(osm_roads.shape)
print(osm_roads.columns.tolist())
print("Number of street segments:", len(osm_roads))
# Out:
# EPSG:25831
# (16541, 21)
# ['u', 'v', 'key', 'osmid', 'highway', 'lanes', 'maxspeed', 'name', 'oneway', 'reversed', 'length', 'access', 'junction', 'ref', 'width', 'est_width', 'tunnel', 'bridge', 'service', 'segment_id', 'geometry']
# Number of street segments: 16541

# %% [markdown]
# ## Traffic Signals - OSM

# %%
signals = ox.features_from_place("Barcelona, Spain", tags={"highway": "traffic_signals"}) #connects to OSM and downloads all features within Barcelona that match the tags you specify
signals = signals[signals.geometry.type == 'Point'].to_crs(osm_roads.crs) #keeps only point geometries and reprojects to match the CRS of noise_streets (otherwise they come in EPSG:4326)
print(signals.crs)
print(signals.columns.tolist())
#signals.plot(figsize=(10, 10),  column='traffic_signals', legend=True, markersize=2)

#https://osmnx.readthedocs.io/en/stable/user-reference.html#osmnx.features.features_from_place
# Out:
# EPSG:25831
# ['geometry', 'highway', 'traffic_signals', 'traffic_signals:direction', 'crossing', 'button_operated', 'tactile_paving', 'traffic_signals:sound', 'traffic_signals:vibration', 'crossing:markings', 'bicycle', 'source', 'kerb', 'wheelchair', 'colour', 'mapillary', 'segregated', 'check_date:traffic_signals:vibration', 'description', 'check_date:traffic_signals:sound', 'crossing:signals', 'direction', 'supervised', 'barrier', 'red_turn:bicycle', 'name', 'name:ca', 'check_date:tactile_paving', 'was:traffic_signals:direction', 'traffic_signals:sound:remote_operated', 'proposed:highway', 'camera:mount', 'camera:type', 'man_made', 'surveillance', 'surveillance:type']

# %%
print(f"Total signals: {len(signals)}")
print(f"Non-null traffic_signals: {signals['traffic_signals'].notna().sum()}")
print(f"Null traffic_signals: {signals['traffic_signals'].isna().sum()}")
print("\nValue counts:")
print(signals['traffic_signals'].value_counts(dropna=False))
# Out:
# Total signals: 6198
# Non-null traffic_signals: 1688
# Null traffic_signals: 4510
#
# Value counts:
# traffic_signals
# NaN                    4510
# signal                 1464
# pedestrian_crossing     149
# blinker                  42
# traffic_lights           25
# crossing                  8
# Name: count, dtype: int64

# %%
ax = signals.plot( markersize=2, figsize=(12, 12))
ax.set_title('Traffic Signals')
ax.set_axis_off()

# %% [markdown]
# ## Transport - OSM

# %%
transport = ox.features_from_place(
    "Barcelona, Spain",
    tags={"railway": ["station", "tram_stop", "subway_entrance"],
          "highway": "bus_stop"})  # all transport — adjust tags as needed
transport = transport[transport.geometry.type == "Point"].to_crs(osm_roads.crs)
transport['transport_type'] = transport['railway'].fillna(transport['highway'])
print(transport.crs)
print(transport.columns.tolist())
# Out:
# EPSG:25831
# ['geometry', 'name', 'name:ca', 'railway', 'wheelchair', 'bench', 'bus', 'highway', 'network', 'operator', 'passenger_information_display', 'public_transport', 'ref', 'route_ref', 'shelter', 'bin', 'lit', 'tactile_paving', 'alt_name', 'alt_name:ca', 'url', 'wheelchair:description', 'bicycle', 'covered', 'level', 'check_date:shelter', 'network:wikidata', 'website', 'operator:wikidata', 'owner', 'owner:wikidata', 'ref:EU:PLC', 'train', 'uic_ref', 'kerb', 'kerb:approach_aid', 'passenger_information_display:speech_output', 'network:bus', 'network:guid', 'network:short', 'network:wikipedia', 'tram', 'departures_board', 'defibrillator:access', 'defibrillator:indoor', 'defibrillator:location', 'defibrillator:location:en', 'defibrillator:wheelchair:access', 'emergency', 'panoramax', 'platforms', 'station', 'subway', 'survey:date', 'wikidata', 'wikimedia_commons', 'wikipedia', 'emergency:fire_extinguisher', 'operator:short', 'panoramax:0', 'addr:city', 'addr:housenumber', 'addr:postcode', 'addr:street', 'description:ru', 'iata', 'internet_access', 'internet_access:fee', 'layer', 'name:es', 'name:fr', 'official_name', 'opening_hours', 'railway:ref', 'ref:FR:sncf:resarail', 'ref:FR:uic8', 'source', 'toilets:wheelchair', 'name:2022', 'disused:public_transport', 'old_name', 'operator:type', 'funicular', 'check_date', 'defibrillator:survey:date', 'indoor', 'share_taxi', 'local_ref', 'access', 'name:ko', 'shelter_type', 'description', 'name:en', 'entrance', 'check_date:bin', 'name:etymology:wikidata', 'was:name', 'note', 'postal_code', 'piano', 'name:ja', 'name:ru', 'name:zh', 'start_date', 'camera:mount', 'camera:type', 'man_made', 'network:metro', 'surveillance', 'surveillance:type', 'surveillance:zone', 'emergency:location', 'emergency_access', 'name:-2023', 'name:ca:-2023', 'location', 'official_ref', 'vehicle', 'ref:ibnr', 'was:ref', 'route:name', 'construction', 'building', 'opening_date', 'amenity', 'building:levels', 'tourism', 'check_date:bench', 'surface', 'transport_type']

# %%
print(f"Total transport points: {len(transport)}")
print(f"Non-null transport points: {transport['transport_type'].notna().sum()}")
print(f"Null transport points: {transport['transport_type'].isna().sum()}")
print("\nValue counts:")
print(transport['transport_type'].value_counts(dropna=False))
# Out:
# Total transport points: 3114
# Non-null transport points: 3114
# Null transport points: 0
#
# Value counts:
# transport_type
# bus_stop           2531
# subway_entrance     369
# station             147
# tram_stop            67
# Name: count, dtype: int64

# %%
ax = transport.plot(column='transport_type', legend=True, markersize=2, figsize=(10, 10))
ax.set_title('Transport')
ax.set_axis_off()

# %% [markdown]
# ## Points Of Interest (POIs) - OSM

# %%
pois = ox.features_from_place(
    "Barcelona, Spain",
    tags={"amenity": True}   # all amenities — adjust tags as needed
)
pois = pois[pois.geometry.type == "Point"].to_crs(osm_roads.crs)
print(pois.crs)
print(pois.columns.tolist())
# Out:
', 'email', 'recycling:PET', 'recycling:beverage_cartons', 'recycling:organic', 'recycling:plastic_bags', 'emergency', 'old_name', 'name:it', 'entrance', 'denomination', 'branch', 'note', 'dog', 'check_date:recycling', 'name:etymology:wikidata', 'office', 'self_service', 'food', 'check_date:collection_times', 'internet_access:access', 'reservation', 'brand:-2024', 'name:-2024', 'operator:-2024', 'drink:club-mate', 'nohousenumber', 'access:covid19', 'alt_name:ca', 'club', 'check_date:capacity', 'fountain', 'brand:ca', 'alcohol', 'contact:mobile', 'healthcare:speciality', 'payment:coins', 'supervised', 'capacity:motorcycle', 'maxwidth', 'collection_times:signed', 'shelter_type', 'addr:housename', 'name:zh', 'name:ru', 'all_you_can_eat', 'int_name', 'opening_hours:covid19', 'min_age', 'internet_access:ssid', 'architect', 'member_of', 'addr:place', 'was:diet:vegan', 'was:diet:vegetarian', 'was:name', 'amenity:-2022', 'payment:telephone_cards', 'material', 'seats', 'colour', 'noref', 'operational_status', 'maxweight', 'motorcar', 'vehicle', 'start_date', 'mapillary', 'bank:network', 'short_name:ca', 'surface', 'fax', 'payment:agilpark', 'building', 'lo ...

# %% [markdown]
# ### Filter and classify POIs

# %%
noisy_categories = ['restaurant', 'cafe', 'bar', 'pub', 'nightclub', 'fast_food', 'food_court','music_venue', 'cinema', 'theatre','shopping_mall', 'shop', 'supermarket', 'marketplace']
pois_noisy = pois[pois['amenity'].isin(noisy_categories)]

sensitive_categories = ['hospital', 'clinic','school', 'kindergarten', 'university', 'research_institute', 'library','social_facility', 'social_centre', 'community_centre']
pois_sensitive = pois[pois['amenity'].isin(sensitive_categories)]

traffic_categories = ['parking', 'parking_lot','taxi']
pois_traffic = pois[pois['amenity'].isin(traffic_categories)]

# %%
ax = pois_noisy.plot(figsize=(10, 10), column='amenity', legend=True, markersize=2)
ax.set_title('POIs Noisy')
ax.set_axis_off()

ax = pois_sensitive.plot(figsize=(10, 10), column='amenity', legend=True, markersize=2)
ax.set_title('POIs Sensitive')
ax.set_axis_off()

ax = pois_traffic.plot(figsize=(10, 10), column='amenity', legend=True, markersize=2)
ax.set_title('POIs Traffic')
ax.set_axis_off()

# %% [markdown]
# ## Signals in 50 m buffer

# %%
# Create 50 m buffer around each street segment
buffered_50 = osm_roads.copy()
buffered_50['geometry'] = buffered_50.geometry.buffer(50)

# %% [markdown]
# ### Count signals per buffer

# %%
signals_join = gpd.sjoin(signals, buffered_50, how="right", predicate="within") #spatial join to combine GeoDataFrames (signals and buffered streets), how="right" to keep all buffered street segments, predicate="within" to match signals that fall within the buffered street segments
signals_count = signals_join.groupby(signals_join.index).size().rename("signal_count") #groupby() to group by the index of the buffered street segments, size() to count the number of signals in each segment, rename() to rename the resulting Series to "signal_count"
signals_count
# Out:
# 0         3
# 1        14
# 2         1
# 3         1
# 4         1
#          ..
# 16536     1
# 16537     1
# 16538     1
# 16539     1
# 16540     1
# Name: signal_count, Length: 16541, dtype: int64

# %% [markdown]
# ## Transport in 100 m buffer

# %%
# Create 100 m buffer around each street segment
buffered_100 = osm_roads.copy()
buffered_100['geometry'] = buffered_100.geometry.buffer(100)

# %%
transport_join = gpd.sjoin(transport, buffered_100, how="right", predicate="within") 
transport_count = transport_join.groupby(transport_join.index).size().rename("poi_count")
transport_count

traffic_join = gpd.sjoin(pois_traffic, buffered_100, how="right", predicate="within") 
traffic_count = traffic_join.groupby(traffic_join.index).size().rename("poi_count")
traffic_count

transport_count + traffic_count
# Out:
# 0        4
# 1        8
# 2        2
# 3        5
# 4        5
#         ..
# 16536    2
# 16537    2
# 16538    2
# 16539    2
# 16540    2
# Name: poi_count, Length: 16541, dtype: int64

# %% [markdown]
# ## POIs noisy in 100 m buffer

# %%
## POI Noisy in 100 m buffer
pois_noisy_join = gpd.sjoin(pois_noisy, buffered_100, how="right", predicate="within") 
pois_noisy_count = pois_noisy_join.groupby(pois_noisy_join.index).size().rename("poi_count")
pois_noisy_count
# Out:
# 0         2
# 1        18
# 2        20
# 3        10
# 4        11
#          ..
# 16536     2
# 16537     2
# 16538     2
# 16539     2
# 16540     2
# Name: poi_count, Length: 16541, dtype: int64

# %% [markdown]
# ## POIs sensitive in 100 m buffer

# %%
## POIs Sensitive in 100 m buffer
pois_sensitive_join = gpd.sjoin(pois_sensitive, buffered_100, how="right", predicate="within")
pois_sensitive_count = pois_sensitive_join.groupby(pois_sensitive_join.index).size().rename("poi_count")
pois_sensitive_count
# Out:
# 0        1
# 1        4
# 2        1
# 3        1
# 4        1
#         ..
# 16536    1
# 16537    1
# 16538    1
# 16539    1
# 16540    1
# Name: poi_count, Length: 16541, dtype: int64

# %% [markdown]
# ## Create Dataset

# %%
dataset = pd.DataFrame({
    "road_id": osm_roads['segment_id'],
    "signals_50": signals_count,
    "transport_100": transport_count + traffic_count,
    "pois_noisy_100": pois_noisy_count,
    "pois_sensitive_100": pois_sensitive_count    
}).fillna(0) #fillna(0) to replace any NaN values (which indicate no signals or POIs in that segment) with 0
dataset.head()
# Out:
#                   road_id  signals_50  transport_100  pois_noisy_100  \
# 0    21638845_885308258_0           3              4               2
# 1  21638845_13175411896_0          14              8              18
# 2     21638865_30343650_0           1              2              20
# 3   21638867_1636238503_0           1              5              10
# 4   21638867_1403082237_0           1              5              11
#
#    pois_sensitive_100
# 0                   1
# 1                   4
# 2                   1
# 3                   1
# 4                   1

# %% [markdown]
# ## Export CSV

# %%
import os
output_dir = "data"
os.makedirs(output_dir, exist_ok=True)

path = os.path.join(output_dir, "osm_points_features.csv")

dataset.to_csv(path, index=False)

print(f"Exported: {path}")
# Out:
# Exported: data\osm_points_features.csv
