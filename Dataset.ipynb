# %%
import geopandas as gpd
import osmnx as ox
import matplotlib.pyplot as plt

# %%
geometry = gpd.read_file(r"C:\Users\cutro\Documents\GitHub\macad\ML-Noise-Prediction\layers\BCN_noise_streets.gpkg")
